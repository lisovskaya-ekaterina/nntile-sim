# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.DataFrame(columns = ['sched', 'hyper', 'n_load', 'sim_time', 'mem_size', 'n_minibatch', 'n_tile'])


data.loc[len(data)] = ['graph_test', 0, 2319, 1.191, 20, 1, 4]
data.loc[len(data)] = ['graph_test', 1, 2319, 1.190, 20, 1, 4]
data.loc[len(data)] = ['graph_test', 2, 1831, 1.121, 20, 1, 4]
data.loc[len(data)] = ['graph_test', 3, 1909, 1.087, 20, 1, 4]
data.loc[len(data)] = ['graph_test', 4, 1811, 1.089, 20, 1, 4]
data.loc[len(data)] = ['new_v2', 1, 1783, 1.082, 20, 1, 4]
data.loc[len(data)] = ['new_v2', 2, 1835, 1.092, 20, 1, 4]
data.loc[len(data)] = ['new_v2', 3, 1809, 1.087, 20, 1, 4]
data.loc[len(data)] = ['new_v2', 4, 1857, 1.089, 20, 1, 4]

data.loc[len(data)] = ['graph_test', 0, 3007, 1.545, 10, 1, 4]
data.loc[len(data)] = ['graph_test', 1, 3111, 1.624, 10, 1, 4]
data.loc[len(data)] = ['graph_test', 2, 1964, 1.161, 10, 1, 4]
data.loc[len(data)] = ['graph_test', 3, 2111, 1.097, 10, 1, 4]
data.loc[len(data)] = ['graph_test', 4, 1864, 1.097, 10, 1, 4]
data.loc[len(data)] = ['new_v2', 1, 1822, 1.083, 10, 1, 4]
data.loc[len(data)] = ['new_v2', 2, 1895, 1.092, 10, 1, 4]
data.loc[len(data)] = ['new_v2', 3, 2160, 1.102, 10, 1, 4]
data.loc[len(data)] = ['new_v2', 4, 2070, 1.103, 10, 1, 4]

data.loc[len(data)] = ['graph_test', 0, 3957, 2.192, 5, 1, 4]
data.loc[len(data)] = ['graph_test', 1, 4116, 2.708, 5, 1, 4]
data.loc[len(data)] = ['graph_test', 2, 3412, 1.211, 5, 1, 4]
data.loc[len(data)] = ['graph_test', 3, 2199, 1.101, 5, 1, 4]
data.loc[len(data)] = ['graph_test', 4, 3177, 1.107, 5, 1, 4]
data.loc[len(data)] = ['new_v2', 1, 3192, 1.099, 5, 1, 4]
data.loc[len(data)] = ['new_v2', 2, 2890, 1.121, 5, 1, 4]
data.loc[len(data)] = ['new_v2', 3, 3218, 1.123, 5, 1, 4]
data.loc[len(data)] = ['new_v2', 4, 2952, 1.126, 5, 1, 4]

data.loc[len(data)] = ['graph_test', 0, 4756, 3.070, 2.5, 1, 4]
data.loc[len(data)] = ['graph_test', 1, 4812, 3.210, 2.5, 1, 4]
data.loc[len(data)] = ['graph_test', 2, 3489, 1.256, 2.5, 1, 4]
data.loc[len(data)] = ['graph_test', 3, 2265, 1.108, 2.5, 1, 4]
data.loc[len(data)] = ['graph_test', 4, 3319, 1.110, 2.5, 1, 4]
data.loc[len(data)] = ['new_v2', 1, 3476, 1.127, 2.5, 1, 4]
data.loc[len(data)] = ['new_v2', 2, 3421, 1.162, 2.5, 1, 4]
data.loc[len(data)] = ['new_v2', 3, 3489, 1.165, 2.5, 1, 4]
data.loc[len(data)] = ['new_v2', 4, 3123, 1.171, 2.5, 1, 4]

'''
data.loc[len(data)] = ['graph_test', 0, 3478, 1.296, 20, 2, 2]
data.loc[len(data)] = ['graph_test', 1, 3476, 1.294, 20, 2, 2]
data.loc[len(data)] = ['graph_test', 2, 2848, 1.169, 20, 2, 2]
data.loc[len(data)] = ['graph_test', 3, 3018, 1.225, 20, 2, 2]
data.loc[len(data)] = ['graph_test', 4, 2954, 1.206, 20, 2, 2]
data.loc[len(data)] = ['new_v2', 1, 2853, 1.199, 20, 2, 2]
data.loc[len(data)] = ['new_v2', 2, 2857, 1.171, 20, 2, 2]

data.loc[len(data)] = ['graph_test', 0, 4115, 1.799, 10, 2, 2]
data.loc[len(data)] = ['graph_test', 1, 4160, 1.716, 10, 2, 2]
data.loc[len(data)] = ['graph_test', 2, 3296, 1.244, 10, 2, 2]
data.loc[len(data)] = ['graph_test', 3, 3203, 1.251, 10, 2, 2]
data.loc[len(data)] = ['graph_test', 4, 3406, 1.241, 10, 2, 2]
data.loc[len(data)] = ['new_v2', 1, 3168, 1.249, 10, 2, 2]
data.loc[len(data)] = ['new_v2', 2, 3282, 1.262, 10, 2, 2]

data.loc[len(data)] = ['graph_test', 0, 5029, 2.464, 5, 2, 2]
data.loc[len(data)] = ['graph_test', 1, 5133, 2.733, 5, 2, 2]
data.loc[len(data)] = ['graph_test', 2, 3910, 1.309, 5, 2, 2]
data.loc[len(data)] = ['graph_test', 3, 3298, 1.266, 5, 2, 2]
data.loc[len(data)] = ['graph_test', 4, 4188, 1.293, 5, 2, 2]
data.loc[len(data)] = ['new_v2', 1, 4213, 1.383, 5, 2, 2]
data.loc[len(data)] = ['new_v2', 2, 4297, 1.377, 5, 2, 2]

data.loc[len(data)] = ['graph_test', 0, 5839, 3.273, 2.5, 2, 2]
data.loc[len(data)] = ['graph_test', 1, 5974, 3.426, 2.5, 2, 2]
data.loc[len(data)] = ['graph_test', 2, 4050, 1.332, 2.5, 2, 2]
data.loc[len(data)] = ['graph_test', 3, 3395, 1.282, 2.5, 2, 2]
data.loc[len(data)] = ['graph_test', 4, 4283, 1.304, 2.5, 2, 2]
data.loc[len(data)] = ['new_v2', 1, 4724, 1.461, 2.5, 2, 2]
data.loc[len(data)] = ['new_v2', 2, 4695, 1.485, 2.5, 2, 2]


data.loc[len(data)] = ['graph_test', 0, 4136, 0.372, 20, 4, 1]
data.loc[len(data)] = ['graph_test', 1, 4148, 0.374, 20, 4, 1]
data.loc[len(data)] = ['graph_test', 2, 3492, 0.239, 20, 4, 1]
data.loc[len(data)] = ['graph_test', 3, 3659, 0.322, 20, 4, 1]
data.loc[len(data)] = ['graph_test', 4, 3594, 0.318, 20, 4, 1]
data.loc[len(data)] = ['new_v2', 1, 3492, 0.239, 20, 4, 1]

data.loc[len(data)] = ['graph_test', 0, 4755, 0.920, 10, 4, 1]
data.loc[len(data)] = ['graph_test', 1, 4776, 0.776, 10, 4, 1]
data.loc[len(data)] = ['graph_test', 2, 3492, 0.239, 10, 4, 1]
data.loc[len(data)] = ['graph_test', 3, 3819, 0.355, 10, 4, 1]
data.loc[len(data)] = ['graph_test', 4, 3787, 0.381, 10, 4, 1]
data.loc[len(data)] = ['new_v2', 1, 3566, 0.240, 10, 4, 1]

data.loc[len(data)] = ['graph_test', 0, 5884, 1.407, 5, 4, 1]
data.loc[len(data)] = ['graph_test', 1, 6109, 1.827, 5, 4, 1]
data.loc[len(data)] = ['graph_test', 2, 4311, 0.330, 5, 4, 1]
data.loc[len(data)] = ['graph_test', 3, 3900, 0.374, 5, 4, 1]
data.loc[len(data)] = ['graph_test', 4, 4532, 0.421, 5, 4, 1]
data.loc[len(data)] = ['new_v2', 1, 4822, 0.562, 5, 4, 1]

data.loc[len(data)] = ['graph_test', 0, 6613, 2.088, 2.5, 4, 1]
data.loc[len(data)] = ['graph_test', 1, 6838, 2.493, 2.5, 4, 1]
data.loc[len(data)] = ['graph_test', 2, 4538, 0.369, 2.5, 4, 1]
data.loc[len(data)] = ['graph_test', 3, 4055, 0.403, 2.5, 4, 1]
data.loc[len(data)] = ['graph_test', 4, 4588, 0.431, 2.5, 4, 1]
data.loc[len(data)] = ['new_v2', 1, 5510, 0.751, 2.5, 4, 1]'''
# Out:
# "\ndata.loc[len(data)] = ['graph_test', 0, 3478, 1.296, 20, 2, 2]\ndata.loc[len(data)] = ['graph_test', 1, 3476, 1.294, 20, 2, 2]\ndata.loc[len(data)] = ['graph_test', 2, 2848, 1.169, 20, 2, 2]\ndata.loc[len(data)] = ['graph_test', 3, 3018, 1.225, 20, 2, 2]\ndata.loc[len(data)] = ['graph_test', 4, 2954, 1.206, 20, 2, 2]\ndata.loc[len(data)] = ['new_v2', 1, 2853, 1.199, 20, 2, 2]\ndata.loc[len(data)] = ['new_v2', 2, 2857, 1.171, 20, 2, 2]\n\ndata.loc[len(data)] = ['graph_test', 0, 4115, 1.799, 10, 2, 2]\ndata.loc[len(data)] = ['graph_test', 1, 4160, 1.716, 10, 2, 2]\ndata.loc[len(data)] = ['graph_test', 2, 3296, 1.244, 10, 2, 2]\ndata.loc[len(data)] = ['graph_test', 3, 3203, 1.251, 10, 2, 2]\ndata.loc[len(data)] = ['graph_test', 4, 3406, 1.241, 10, 2, 2]\ndata.loc[len(data)] = ['new_v2', 1, 3168, 1.249, 10, 2, 2]\ndata.loc[len(data)] = ['new_v2', 2, 3282, 1.262, 10, 2, 2]\n\ndata.loc[len(data)] = ['graph_test', 0, 5029, 2.464, 5, 2, 2]\ndata.loc[len(data)] = ['graph_test', 1, 5133, 2.
# ...

# %%
fig = plt.figure(figsize=(9, 4))
gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[5, 4])

# Находим минимальное и максимальное значения 'sim_time' для всех данных
vmin = data['sim_time'].min()
vmax = data['sim_time'].max()

# Функция для создания heatmap с общей цветовой шкалой
def create_heatmap(data, ax, xlabel, ylabel, vmin, vmax):
    heatmap_data = data.pivot_table(values='sim_time', index='mem_size', columns='hyper')
    sns.heatmap(heatmap_data, annot=True, fmt=".3f", cmap="RdYlGn_r", ax=ax, cbar=False, vmin=vmin, vmax=vmax, yticklabels=heatmap_data.index) # cbar=False для отключения отдельных шкал
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.invert_yaxis()

# Первый график (graph_test)
ax1 = fig.add_subplot(gs[0])
df = data.query('sched == "graph_test"')
create_heatmap(df, ax1, 'Значение переменной окружения\nSTARPU_SCHED_GRAPH_TEST_DESCENDANTS\n\n(а) graph_test', 'Объем памяти, ГБ', vmin, vmax)

# Второй график (new_v2)
ax2 = fig.add_subplot(gs[1])
df = data.query('sched == "new_v2"')
create_heatmap(df, ax2, 'Значение переменной окружения\nN_TILE_HYPER\n\n(б) multi_phase_tile', 'Объем памяти, ГБ', vmin, vmax)


plt.tight_layout()

# Добавление общей цветовой шкалы
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
# Нормализация цветовой шкалы
norm = plt.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap="RdYlGn_r", norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cbar_ax)

plt.show()

# %%
fig = plt.figure(figsize=(9, 4))
gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[5, 4])

# Находим минимальное и максимальное значения 'n_load' для всех данных
vmin = data['n_load'].min()
vmax = data['n_load'].max()

# Функция для создания heatmap с общей цветовой шкалой
def create_heatmap(data, ax, xlabel, ylabel, vmin, vmax):
    heatmap_data = data.pivot_table(values='n_load', index='mem_size', columns='hyper')
    sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="RdYlGn_r", ax=ax, cbar=False, vmin=vmin, vmax=vmax, yticklabels=heatmap_data.index) # cbar=False для отключения отдельных шкал
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.invert_yaxis()

# Первый график (graph_test)
ax1 = fig.add_subplot(gs[0])
df = data.query('sched == "graph_test"')
create_heatmap(df, ax1, 'Значение переменной окружения\nSTARPU_SCHED_GRAPH_TEST_DESCENDANTS\n\n(а) graph_test', 'Объем памяти, ГБ', vmin, vmax)

# Второй график (new_v2)
ax2 = fig.add_subplot(gs[1])
df = data.query('sched == "new_v2"')
create_heatmap(df, ax2, 'Значение переменной окружения\nN_TILE_HYPER\n\n(б) multi_phase_tile', 'Объем памяти, ГБ', vmin, vmax)


plt.tight_layout()

# Добавление общей цветовой шкалы
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
#  Нормализация цветовой шкалы
norm = plt.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap="RdYlGn_r", norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cbar_ax)


plt.show()
