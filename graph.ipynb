# %%
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering

# %%
def remove_spaces_from_list(lst):
    return [value for value in lst if value != '']

# %%
records = []
with open('examples/tasks_mbs4_mbst4_nlayer1.rec', 'r', encoding='utf-8') as file:
    record = {}
    for line in file:
        line = line.strip()
        if line:
            key, value = line.split(': ', 1)
            record[key] = value
        else:
            if record:
                records.append(record)
                record = {}

    if record:
        records.append(record)

# %%
i_batch = 0

# %%
my_records = []
JobIDs = []
names_list = set()
i_minibatch_list = set()
task_fields = ['Name', 'DependsOn', 'JobId', 'EndTime', 'StartTime', 'Iteration', 'Modes', 'Sizes']
for record in records:
  if 'Iteration' in record.keys():
    iter = [int(elem) for elem in record['Iteration'].split()]
    if all(element in record for element in task_fields) and record['Name'][0] != '_' and record['Name'] != 'task_build' and iter[0] == i_batch and len(iter) == 2:
      my_records.append(record)
      JobIDs.append(record['JobId'])
      names_list.add(record['Name'])
      i_minibatch_list.add(iter[1])

# %%
G_list = [nx.DiGraph() for _ in range(len(i_minibatch_list))]

for record in my_records:
    job_id = record["JobId"]
    depends_on = record.get("DependsOn")
    i_minibatch = int(record["Iteration"][2:])

    if i_minibatch < len(i_minibatch_list):

        # Добавляем вершину
        G_list[i_minibatch].add_node(job_id, name=record["Name"])

        # Если есть зависимости, добавляем ориентированные рёбра для каждого из DependsOn
        if depends_on:
            # Если DependsOn несколько, разделяем по пробелам или запятой
            dependencies = depends_on.split()  # Разделяем по пробелам, если зависимость в виде списка
            for dep in dependencies:
              if dep in JobIDs:
                G_list[i_minibatch].add_edge(dep, job_id)  # Добавляем ориентированное ребро от зависимой задачи
    else:
        # Добавляем вершину
        G_list[-1].add_node(job_id, name=record["Name"])

        # Если есть зависимости, добавляем ориентированные рёбра для каждого из DependsOn
        if depends_on:
            # Если DependsOn несколько, разделяем по пробелам или запятой
            dependencies = depends_on.split()  # Разделяем по пробелам, если зависимость в виде списка
            for dep in dependencies:
              if dep in JobIDs:
                G_list[-1].add_edge(dep, job_id)  # Добавляем ориентированное ребро от зависимой задачи

# %%
for G in G_list:
    print(len(G))
# Out:
# 128
# 42

# %%
G = G_list[0]

# %%
# Функция для разбиения графа на num_parts подграфа
def split_graph_into_parts(graph, num_parts):
    # Получаем матрицу смежности
    adjacency_matrix = nx.to_numpy_array(graph)
    
    # Применяем spectral clustering для разбиения на части
    clustering = SpectralClustering(n_clusters=num_parts, affinity='precomputed', random_state=42)
    labels = clustering.fit_predict(adjacency_matrix)
    
    # Создаём подграфы для каждого кластера
    subgraphs = []
    for i in range(num_parts):
        nodes_in_cluster = [node for node, label in zip(graph.nodes, labels) if label == i]
        subgraph = graph.subgraph(nodes_in_cluster).copy()
        subgraphs.append(subgraph)
    
    return subgraphs

# %%
# Разбиваем граф на 4 подграфа
subgraphs = split_graph_into_parts(G, num_parts=1)

# Печатаем информацию о каждом подграфе
for i, subgraph in enumerate(subgraphs):
    print(f"Подграф {i+1}: {len(subgraph.nodes)} задач, {len(subgraph.edges)} рёбер")
# Out:
# Подграф 1: 128 задач, 169 рёбер
# /Users/lisovskaya_ekaterina/Library/Python/3.9/lib/python/site-packages/sklearn/manifold/_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# /Users/lisovskaya_ekaterina/Library/Python/3.9/lib/python/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
G = subgraphs[0]
isolated_nodes = [node for node in G.nodes if G.degree(node) == 0]
G.remove_nodes_from(isolated_nodes)

# %%
len(G.nodes)
# Out:
# 127

# %%
len(G.edges)
# Out:
# 169

# %%
options = {
    'node_color': 'blue', #  Цвет узлов
    'node_size': 7,      # Размер узлов (уменьшите, если граф слишком плотный)
    'edge_color': 'gray', # Цвет ребер
    'width': 1,        # Толщина ребер
    'alpha': 0.7        # Прозрачность
}

#pos = nx.spring_layout(G, seed=42)
pos = nx.spectral_layout(G)
plt.figure(figsize=(12,4))
nx.draw(G, pos, **options)
plt.show()

# %%
#  Для интерактивной визуализации:
import plotly.graph_objects as go

#  Преобразуем networkx граф в plotly формат
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=False,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=5,
        line_width=0))


fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                 )
fig.show()
