# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
def remove_spaces_from_list(lst):
    return [value for value in lst if value != '']

# %%
records = []
with open('examples/iteration_tasks.rec', 'r', encoding='utf-8') as file:
    record = {}
    for line in file:
        line = line.strip()  # Убираем лишние пробелы и символы перевода строки
        if line:  # Если строка не пустая
            key, value = line.split(': ', 1)  # Разделяем по ": "
            record[key] = value
        else:  # Пустая строка означает конец записи
            if record:  # Если накоплена запись
                records.append(record)
                record = {}  # Очищаем для следующей записи

    if record:  # Добавляем последнюю запись, если файл не заканчивается пустой строкой
        records.append(record)

# %%
i_batch = 0

# %%
my_records = []
JobIDs = []
names_list = set()
i_minibatch_list = set()
task_fields = ['Name', 'DependsOn', 'JobId', 'EndTime', 'StartTime', 'Iteration', 'Modes', 'Sizes']
for record in records:
  if 'Iteration' in record.keys():
    iter = [int(elem) for elem in record['Iteration'].split()]
    if all(element in record for element in task_fields) and record['Name'][0] != '_' and record['Name'] != 'task_build' and iter[0] == i_batch and len(iter) == 2:
      my_records.append(record)
      JobIDs.append(record['JobId'])
      names_list.add(record['Name'])
      i_minibatch_list.add(iter[1])

# %%
len(my_records)
# Out:
# 18814

# %%
G_list = [nx.DiGraph() for _ in range(len(i_minibatch_list))]

for record in my_records:
    job_id = record["JobId"]
    depends_on = record.get("DependsOn")
    i_minibatch = int(record["Iteration"][2:])

    if i_minibatch < len(i_minibatch_list):

        # Добавляем вершину
        G_list[i_minibatch].add_node(job_id, name=record["Name"])

        # Если есть зависимости, добавляем ориентированные рёбра для каждого из DependsOn
        if depends_on:
            # Если DependsOn несколько, разделяем по пробелам или запятой
            dependencies = depends_on.split()  # Разделяем по пробелам, если зависимость в виде списка
            for dep in dependencies:
              if dep in JobIDs:
                G_list[i_minibatch].add_edge(dep, job_id)  # Добавляем ориентированное ребро от зависимой задачи
    else:
        # Добавляем вершину
        G_list[-1].add_node(job_id, name=record["Name"])

        # Если есть зависимости, добавляем ориентированные рёбра для каждого из DependsOn
        if depends_on:
            # Если DependsOn несколько, разделяем по пробелам или запятой
            dependencies = depends_on.split()  # Разделяем по пробелам, если зависимость в виде списка
            for dep in dependencies:
              if dep in JobIDs:
                G_list[-1].add_edge(dep, job_id)  # Добавляем ориентированное ребро от зависимой задачи

# %%
for G in G_list:
    print(len(G))
# Out:
# 2089
# 2367
# 2367
# 2367
# 2367
# 2367
# 2367
# 2367
# 438

# %%
for i in range(len(G_list)):
    for j in range(i + 1,len(G_list)):
        print(f'{i} - {j}: {nx.is_isomorphic(G_list[i], G_list[j])}')
# Out:
# 0 - 1: False
# 0 - 2: False
# 0 - 3: False
# 0 - 4: False
# 0 - 5: False
# 0 - 6: False
# 0 - 7: False
# 0 - 8: False
# 1 - 2: True
# 1 - 3: True
# 1 - 4: True
# 1 - 5: True
# 1 - 6: True
# 1 - 7: True
# 1 - 8: False
# 2 - 3: True
# 2 - 4: True
# 2 - 5: True
# 2 - 6: True
# 2 - 7: True
# 2 - 8: False
# 3 - 4: True
# 3 - 5: True
# 3 - 6: True
# 3 - 7: True
# 3 - 8: False
# 4 - 5: True
# 4 - 6: True
# 4 - 7: True
# 4 - 8: False
# 5 - 6: True
# 5 - 7: True
# 5 - 8: False
# 6 - 7: True
# 6 - 8: False
# 7 - 8: False

# %%
G = G_list[1]

# %%
options = {
    'node_color': 'blue', #  Цвет узлов
    'node_size': 2,      # Размер узлов (уменьшите, если граф слишком плотный)
    'edge_color': 'gray', # Цвет ребер
    'width': 0.1,        # Толщина ребер
    'alpha': 0.7        # Прозрачность
}

pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, **options)
plt.show()

# %%
#  Для интерактивной визуализации:
import plotly.graph_objects as go

#  Преобразуем networkx граф в plotly формат
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=False,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=5,
        line_width=0))


fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                 )
fig.show()
